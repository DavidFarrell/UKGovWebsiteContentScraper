# %%
import json
import pandas as pd
from collections import Counter
from typing import Dict, List

# %%
# Load the JSON file
file_path = 'data/gov_pages_with_synthetic_content.json'

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

print(f"Total number of documents: {len(data)}")
# Out:
# Total number of documents: 157

# %%
# Analyze document types
doc_types = Counter(page['document_type'] for page in data)
print("Document types distribution:")
for doc_type, count in doc_types.most_common():
    print(f"- {doc_type}: {count}")
# Out:
# Document types distribution:
# - guide: 76
# - answer: 45
# - detailed_guide: 21
# - step_by_step_nav: 8
# - guidance: 6
# - statutory_guidance: 1

# %%
# Analyze synthetic data coverage
synthetic_count = sum(1 for page in data if page.get('synthetic_data'))
print(f"\nSynthetic data coverage:")
print(f"Documents with synthetic data: {synthetic_count}")
print(f"Coverage percentage: {(synthetic_count/len(data))*100:.1f}%")
# Out:
# Synthetic data coverage:
# Documents with synthetic data: 157
# Coverage percentage: 100.0%

# %%
# Analyze snippets
total_snippets = 0
snippets_per_doc = []

for page in data:
    if page.get('synthetic_data') and page['synthetic_data'].get('article_snippets'):
        num_snippets = len(page['synthetic_data']['article_snippets']['snippets'])
        total_snippets += num_snippets
        snippets_per_doc.append(num_snippets)

print(f"\nSnippet statistics:")
print(f"Total snippets across all documents: {total_snippets}")
print(f"Average snippets per document: {sum(snippets_per_doc)/len(snippets_per_doc):.1f}")
print(f"Min snippets in a document: {min(snippets_per_doc)}")
print(f"Max snippets in a document: {max(snippets_per_doc)}")
# Out:
# Snippet statistics:
# Total snippets across all documents: 1293
# Average snippets per document: 8.2
# Min snippets in a document: 1
# Max snippets in a document: 24

# %%
def display_random_synthetic_example():
    import random
    
    # Get a random page with synthetic data
    pages_with_synthetic = [p for p in data if p.get('synthetic_data')]
    page_index = random.randint(0, len(pages_with_synthetic) - 1)
    sample_page = pages_with_synthetic[page_index]
    
    print(f"Document Index: {page_index} (save this number to revisit this example)")
    print(f"Title: {sample_page['title']}")
    print(f"Document Type: {sample_page['document_type']}")
    print("-" * 80)
    
    # Original content preview (first 200 chars)
    print("\nORIGINAL CONTENT PREVIEW:")
    print(sample_page['details']['body'][:200], "...\n")
    print("-" * 80)
    
    # Poorly written version preview
    print("\nPOORLY WRITTEN VERSION PREVIEW:")
    print(sample_page['synthetic_data']['poorly_written_article'][:200], "...\n")
    print("-" * 80)
    
    # Show all snippet pairs
    snippets = sample_page['synthetic_data']['article_snippets']['snippets']
    print(f"\nNumber of snippets: {len(snippets)}")
    
    for i, snippet in enumerate(snippets, 1):
        print(f"\nSNIPPET PAIR {i}:")
        print("\nWell-written:")
        print(snippet['well_written_snippet'])
        print("\nBadly-written:")
        print(snippet['badly_written_snippet'])
        print("-" * 80)

# To see a specific example, you can modify this to:
# display_specific_example(saved_index)
display_random_synthetic_example()
# Out:
# Document Index: 72 (save this number to revisit this example)
# Title: The National Minimum Wage and Living Wage
# Document Type: guide
# --------------------------------------------------------------------------------
#
# ORIGINAL CONTENT PREVIEW:
# ## Overview
#
# The [minimum wage a worker should get](/national-minimum-wage-rates) depends on their age and if they’re an apprentice.
#
# The National Minimum Wage is the minimum pay per hour almost all  ...
#
# --------------------------------------------------------------------------------
#
# POORLY WRITTEN VERSION PREVIEW:
# Okay, so let’s talk about minimum wage stuff really quick. So like, minimum wage kinda depends on your age and if you’re an apprentice, right? The National Minimum Wage is basically the minimum pay yo ...
#
# --------------------------------------------------------------------------------
#
# Number of snippets: 12
#
# SNIPPET PAIR 1:
#
# Well-written:
# The minimum wage a worker should receive depends on their age and whether they are an apprentice. The National Minimum Wage is the lowest pay per hour that nearly all workers are entitled to receive, while the National Living Wage is a higher rate applicable to workers aged 21 and over. Every employer, regardless of size, is legally required to pay the appropriate minimum wage.
#
# Badly-written:
# The MINIMUM WAGE, which is like this totally essential monetary remuneration that every person deserving to be deemed a WORKER should receive, is, as per the most recent CONVENTION, remarkably contingent upon variables such as the individual's age, which, if I may point out, is super crucial, and their status as an apprentice, which is yet another layer of complexity. Oh, and by the way, the so-called National Minimum Wage is essentially this foundational level of pay that, believe it or not, nearly ALL workforce participants have a RIGHT to, while the National Living Wage, which is like totally a different realm, kicks in when someone is 21 years old or older - mind you, does size matter for employers in terms of wage compliance? Absolutely not!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 2:
#
# Well-written:
# To verify the correct minimum wage has been paid, workers can use the available minimum wage calculators. There are distinct calculators designed for workers and employers. Workers should utilize the dedicated calculator for checking their own wages, whereas employers can confirm their compliance using the calculator designed for them. Additionally, guidance is offered for calculating the minimum wage for various types of work.
#
# Badly-written:
# Uh-oh, so like, if you're figuring out whether you’ve been compensated at the correct minimum wage, there are these calculators – pretty nifty, huh? Just think of them as magical NUMBER crunchers that can check if you've been PAID what you DESERVE, which is absolutely crucial for maintaining that cash flow in your pocket because who wants to be underpaid, amirite? There’s this one for the WORKERS, and then there's another – and, oh boy, employers better hope they’re NOT falling short, because like, that would be super embarrassing for them, right? Plus, there’s this guidance for how to do all the numbery things for different TYPES of work you might be doing, so don’t miss out on that riveting info!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 3:
#
# Well-written:
# Workers categorized as 'workers' must be at least of school leaving age to qualify for the National Minimum Wage, while those seeking the National Living Wage must be 21 or over. Any contracts stipulating payment below the minimum wage are not legally binding, and workers are entitled to the minimum wage regardless of circumstances. It is important to note that all types of workers, including part-time workers and apprentices, have rights to the minimum wage.
#
# Badly-written:
# So like, if you’re under the umbrella of being a WORKER (whatever that entails), which, by the way, you basically need to be, like, of school-leaving age (which is kind of a given, really), you can totally expect to snag yourself that National Minimum Wage – but only if you’re not, you know, under 21, because then it gets SUPER complicated because there’s this other thing called the National Living Wage which, I mean, who knew there were so many rules? And like, just a heads up, any shady contracts that try to lowball you below the MINIMUM wage? Yeah, those are as good as toilet paper because they ain’t legally binding - sproing! But here’s the kicker – whether you’re a casual worker, an APPRENTICE or whatever, your RIGHT to the minimum wage is like cast in stone, dude.
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 4:
#
# Well-written:
# Apprentices are entitled to the apprentice rate if they are under 19 or 19 and in the first year of their apprenticeship. Those who are over 19 and have completed their first year are entitled to the minimum wage appropriate for their age.
#
# Badly-written:
# Alright, so let's get real about Apprentices – if you’re a young buck under 19 or, like, someone who’s 19 and just starting out in your apprenticeship journey, then guess what? You qualify for this magical land known as the apprentice rate - sounds fancy, huh? But hold your horses! If you’re hitting that big two-oh and have like, popped your cherry on your first year, it’s time to graduate to the real-deal minimum wage that fits your advanced age because, believe it or not, age matters in this money game!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 5:
#
# Well-written:
# Certain categories of workers do not qualify for the National Minimum Wage or National Living Wage. These include self-employed people, company directors, volunteers, and members of the armed forces, among others. It is crucial for employers offering internships to check if the intern is entitled to receive the minimum wage.
#
# Badly-written:
# Let’s just rip the band-aid off – there are actually people who totally don’t get the warm fuzzy minimum wage, like self-employed peeps who are all on their own adventure, or like highfalutin company directors with their fancy titles. Then you've got those super noble volunteers doing their thing WITHOUT, like, cash flow, or even our brave men and women in the armed forces who just don’t fit into this whole minimum wage picture – wild, right? And hey, if somebody claims to be giving you an ‘internship’ – which, by the way, is often code for, 'I just don’t want to pay you' – you should really involve yourself in a deep dive investigation because like, who’s to say they’re not just trying to pull a fast one?
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 6:
#
# Well-written:
# Voluntary work is identified as work for which individuals are only compensated with limited benefits such as reasonable travel or meal expenses. Generally, this includes positions within charities or statutory bodies.
#
# Badly-written:
# So, you’re out there doing this thing called voluntary work, right? And like, don't you just LOVE when the only compensation is a pat on the back and perhaps a bus fare or a sandwich now and then? That’s just SO fulfilling, isn’t it?! This kind of noble endeavor typically pops up when you’re dealing with charities or other government-related funployment activities - just don’t expect a paycheck to materialize because that’s not how this gracious world works!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 7:
#
# Well-written:
# Employers must adhere to the regulations regarding the minimum wage to ensure compliance with the law. It’s essential to familiarize oneself with the applicable minimum wage rates and the worker categories they correspond to.
#
# Badly-written:
# Okay, so just a little heads up to all you employers out there who might be skating on thin ice regarding the law - you’ve got to shell out the correct minimum wage, no ifs or buts about it! This is like, one of those rules for the book that you can’t just ignore, because compliance is key, right? You really should like, dive into the nitty-gritty about those ever-changing minimum wage rates and make sure you know who’s who in the zoo regarding who actually gets what – it’s like a real-life treasure hunt!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 8:
#
# Well-written:
# There are several payments that must not be included in minimum wage calculations, such as employer-use payments, reimbursements for job-related purchases, and tips. Conversely, certain payments must be included in calculations, such as National Insurance contributions and wage advances.
#
# Badly-written:
# Whoa there! Did you know there are like, a bunch of things that you CANNOT count when you’re doing the math for minimum wage? Yup, anything that’s like, for the employer’s own kicks or when they’ve covered something for travel but don’t bother to pass that money back to you, or tips - those don’t count, like, AT ALL. However, do keep in mind that if we’re talking about Income Tax or when you borrow money from your employer - oh yeah, that stuff TOTALLY comes into play when the pay calculation rolls around, so keep that in your back pocket!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 9:
#
# Well-written:
# Pay reference periods are defined according to payroll frequency, such as weekly, monthly, or bi-weekly. Workers should be paid the minimum wage on average over the specified pay reference period.
#
# Badly-written:
# Okay, let's chat about these pay reference periods – super interesting stuff! Basically, they’re set according to how often you get paid, whether it’s weekly, monthly, or even like every ten days—oh boy, talk about diversifying your paycheck schedule, right? But FYI, you can’t have these reference periods stretching longer than 31 days, otherwise, it’s just madness! And of course, let’s not forget the golden rule: you MUST be raking in that minimum wage – on average, of course – during this magical time frame. Because if that’s NOT happening, you definitely need to shout at someone, like, right now!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 10:
#
# Well-written:
# If workers believe they are being paid below the minimum wage, they should first address the issue directly with their employers. Should this not yield results, they can formally request to see payment records and may reach out to Acas for confidential assistance.
#
# Badly-written:
# So, if you’re sitting there thinking, ‘Gee, my paycheck really seems off,’ the first thing you should do is get brave and chat with your boss about it, like, face to face - awkward, I know! If that doesn’t work out, you can totally demand to see those payment records, just like you have some kind of right to play detective or whatever. And don’t forget, if things get real sticky, there’s always Acas – the kinda confidential superhero of employment disputes – to swoop in and help!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 11:
#
# Well-written:
# If an employer refuses to pay owed wages, HMRC will issue a notice for the arrears as well as a fine. Moreover, HMRC retains the authority to take employers to court on behalf of the worker should they continue to refuse payment.
#
# Badly-written:
# Here’s the lowdown: if you find yourself in the unfortunate reality where your employer is pulling a vanishing act on your wages, HMRC is there to swoop in with their Notice of Arrears and, like, slap a fine on your employer too! And let's be real here – if they keep playing hardball and act all stubborn about it, HMRC isn’t just gonna stand back and wave goodbye – they can actually drag them to court on your behalf! How about that for a turn of events, huh?
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 12:
#
# Well-written:
# Workers have the option to approach an employment tribunal directly for disputes regarding minimum wage or unfair dismissal if they have been terminated due to a wage-related argument.
#
# Badly-written:
# So, if you find yourself in the mind-boggling labyrinth of wage disputes and think your minimum wage rights are being stomped on, you can totally skip the chit-chat with your boss and just stroll right up to an employment tribunal, like a boss yourself! And oh my goodness, if they dared to dismiss you over this very issue? Well, guess what! You can also throw an unfair dismissal claim into the mix, which is like a double whammy in your legal favor – how cool is that?!
# --------------------------------------------------------------------------------

# %%
def display_specific_example(index: int):
    pages_with_synthetic = [p for p in data if p.get('synthetic_data')]
    if 0 <= index < len(pages_with_synthetic):
        sample_page = pages_with_synthetic[index]
        print(f"Document Index: {index}")
        print(f"Title: {sample_page['title']}")
        print(f"Document Type: {sample_page['document_type']}")
        print("-" * 80)
        
        # Original content preview (first 200 chars)
        print("\nORIGINAL CONTENT PREVIEW:")
        print(sample_page['details']['body'][:200], "...\n")
        print("-" * 80)
        
        # Poorly written version preview
        print("\nPOORLY WRITTEN VERSION PREVIEW:")
        print(sample_page['synthetic_data']['poorly_written_article'][:200], "...\n")
        print("-" * 80)
        
        # Show all snippet pairs
        snippets = sample_page['synthetic_data']['article_snippets']['snippets']
        print(f"\nNumber of snippets: {len(snippets)}")
        
        for i, snippet in enumerate(snippets, 1):
            print(f"\nSNIPPET PAIR {i}:")
            print("\nWell-written:")
            print(snippet['well_written_snippet'])
            print("\nBadly-written:")
            print(snippet['badly_written_snippet'])
            print("-" * 80)
    else:
        print(f"Index {index} is out of range. Please use an index between 0 and {len(pages_with_synthetic)-1}")
        
# Example usage:
display_specific_example(72)  # To revisit example #42
# Out:
# Document Index: 72
# Title: The National Minimum Wage and Living Wage
# Document Type: guide
# --------------------------------------------------------------------------------
#
# ORIGINAL CONTENT PREVIEW:
# ## Overview
#
# The [minimum wage a worker should get](/national-minimum-wage-rates) depends on their age and if they’re an apprentice.
#
# The National Minimum Wage is the minimum pay per hour almost all  ...
#
# --------------------------------------------------------------------------------
#
# POORLY WRITTEN VERSION PREVIEW:
# Okay, so let’s talk about minimum wage stuff really quick. So like, minimum wage kinda depends on your age and if you’re an apprentice, right? The National Minimum Wage is basically the minimum pay yo ...
#
# --------------------------------------------------------------------------------
#
# Number of snippets: 12
#
# SNIPPET PAIR 1:
#
# Well-written:
# The minimum wage a worker should receive depends on their age and whether they are an apprentice. The National Minimum Wage is the lowest pay per hour that nearly all workers are entitled to receive, while the National Living Wage is a higher rate applicable to workers aged 21 and over. Every employer, regardless of size, is legally required to pay the appropriate minimum wage.
#
# Badly-written:
# The MINIMUM WAGE, which is like this totally essential monetary remuneration that every person deserving to be deemed a WORKER should receive, is, as per the most recent CONVENTION, remarkably contingent upon variables such as the individual's age, which, if I may point out, is super crucial, and their status as an apprentice, which is yet another layer of complexity. Oh, and by the way, the so-called National Minimum Wage is essentially this foundational level of pay that, believe it or not, nearly ALL workforce participants have a RIGHT to, while the National Living Wage, which is like totally a different realm, kicks in when someone is 21 years old or older - mind you, does size matter for employers in terms of wage compliance? Absolutely not!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 2:
#
# Well-written:
# To verify the correct minimum wage has been paid, workers can use the available minimum wage calculators. There are distinct calculators designed for workers and employers. Workers should utilize the dedicated calculator for checking their own wages, whereas employers can confirm their compliance using the calculator designed for them. Additionally, guidance is offered for calculating the minimum wage for various types of work.
#
# Badly-written:
# Uh-oh, so like, if you're figuring out whether you’ve been compensated at the correct minimum wage, there are these calculators – pretty nifty, huh? Just think of them as magical NUMBER crunchers that can check if you've been PAID what you DESERVE, which is absolutely crucial for maintaining that cash flow in your pocket because who wants to be underpaid, amirite? There’s this one for the WORKERS, and then there's another – and, oh boy, employers better hope they’re NOT falling short, because like, that would be super embarrassing for them, right? Plus, there’s this guidance for how to do all the numbery things for different TYPES of work you might be doing, so don’t miss out on that riveting info!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 3:
#
# Well-written:
# Workers categorized as 'workers' must be at least of school leaving age to qualify for the National Minimum Wage, while those seeking the National Living Wage must be 21 or over. Any contracts stipulating payment below the minimum wage are not legally binding, and workers are entitled to the minimum wage regardless of circumstances. It is important to note that all types of workers, including part-time workers and apprentices, have rights to the minimum wage.
#
# Badly-written:
# So like, if you’re under the umbrella of being a WORKER (whatever that entails), which, by the way, you basically need to be, like, of school-leaving age (which is kind of a given, really), you can totally expect to snag yourself that National Minimum Wage – but only if you’re not, you know, under 21, because then it gets SUPER complicated because there’s this other thing called the National Living Wage which, I mean, who knew there were so many rules? And like, just a heads up, any shady contracts that try to lowball you below the MINIMUM wage? Yeah, those are as good as toilet paper because they ain’t legally binding - sproing! But here’s the kicker – whether you’re a casual worker, an APPRENTICE or whatever, your RIGHT to the minimum wage is like cast in stone, dude.
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 4:
#
# Well-written:
# Apprentices are entitled to the apprentice rate if they are under 19 or 19 and in the first year of their apprenticeship. Those who are over 19 and have completed their first year are entitled to the minimum wage appropriate for their age.
#
# Badly-written:
# Alright, so let's get real about Apprentices – if you’re a young buck under 19 or, like, someone who’s 19 and just starting out in your apprenticeship journey, then guess what? You qualify for this magical land known as the apprentice rate - sounds fancy, huh? But hold your horses! If you’re hitting that big two-oh and have like, popped your cherry on your first year, it’s time to graduate to the real-deal minimum wage that fits your advanced age because, believe it or not, age matters in this money game!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 5:
#
# Well-written:
# Certain categories of workers do not qualify for the National Minimum Wage or National Living Wage. These include self-employed people, company directors, volunteers, and members of the armed forces, among others. It is crucial for employers offering internships to check if the intern is entitled to receive the minimum wage.
#
# Badly-written:
# Let’s just rip the band-aid off – there are actually people who totally don’t get the warm fuzzy minimum wage, like self-employed peeps who are all on their own adventure, or like highfalutin company directors with their fancy titles. Then you've got those super noble volunteers doing their thing WITHOUT, like, cash flow, or even our brave men and women in the armed forces who just don’t fit into this whole minimum wage picture – wild, right? And hey, if somebody claims to be giving you an ‘internship’ – which, by the way, is often code for, 'I just don’t want to pay you' – you should really involve yourself in a deep dive investigation because like, who’s to say they’re not just trying to pull a fast one?
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 6:
#
# Well-written:
# Voluntary work is identified as work for which individuals are only compensated with limited benefits such as reasonable travel or meal expenses. Generally, this includes positions within charities or statutory bodies.
#
# Badly-written:
# So, you’re out there doing this thing called voluntary work, right? And like, don't you just LOVE when the only compensation is a pat on the back and perhaps a bus fare or a sandwich now and then? That’s just SO fulfilling, isn’t it?! This kind of noble endeavor typically pops up when you’re dealing with charities or other government-related funployment activities - just don’t expect a paycheck to materialize because that’s not how this gracious world works!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 7:
#
# Well-written:
# Employers must adhere to the regulations regarding the minimum wage to ensure compliance with the law. It’s essential to familiarize oneself with the applicable minimum wage rates and the worker categories they correspond to.
#
# Badly-written:
# Okay, so just a little heads up to all you employers out there who might be skating on thin ice regarding the law - you’ve got to shell out the correct minimum wage, no ifs or buts about it! This is like, one of those rules for the book that you can’t just ignore, because compliance is key, right? You really should like, dive into the nitty-gritty about those ever-changing minimum wage rates and make sure you know who’s who in the zoo regarding who actually gets what – it’s like a real-life treasure hunt!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 8:
#
# Well-written:
# There are several payments that must not be included in minimum wage calculations, such as employer-use payments, reimbursements for job-related purchases, and tips. Conversely, certain payments must be included in calculations, such as National Insurance contributions and wage advances.
#
# Badly-written:
# Whoa there! Did you know there are like, a bunch of things that you CANNOT count when you’re doing the math for minimum wage? Yup, anything that’s like, for the employer’s own kicks or when they’ve covered something for travel but don’t bother to pass that money back to you, or tips - those don’t count, like, AT ALL. However, do keep in mind that if we’re talking about Income Tax or when you borrow money from your employer - oh yeah, that stuff TOTALLY comes into play when the pay calculation rolls around, so keep that in your back pocket!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 9:
#
# Well-written:
# Pay reference periods are defined according to payroll frequency, such as weekly, monthly, or bi-weekly. Workers should be paid the minimum wage on average over the specified pay reference period.
#
# Badly-written:
# Okay, let's chat about these pay reference periods – super interesting stuff! Basically, they’re set according to how often you get paid, whether it’s weekly, monthly, or even like every ten days—oh boy, talk about diversifying your paycheck schedule, right? But FYI, you can’t have these reference periods stretching longer than 31 days, otherwise, it’s just madness! And of course, let’s not forget the golden rule: you MUST be raking in that minimum wage – on average, of course – during this magical time frame. Because if that’s NOT happening, you definitely need to shout at someone, like, right now!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 10:
#
# Well-written:
# If workers believe they are being paid below the minimum wage, they should first address the issue directly with their employers. Should this not yield results, they can formally request to see payment records and may reach out to Acas for confidential assistance.
#
# Badly-written:
# So, if you’re sitting there thinking, ‘Gee, my paycheck really seems off,’ the first thing you should do is get brave and chat with your boss about it, like, face to face - awkward, I know! If that doesn’t work out, you can totally demand to see those payment records, just like you have some kind of right to play detective or whatever. And don’t forget, if things get real sticky, there’s always Acas – the kinda confidential superhero of employment disputes – to swoop in and help!
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 11:
#
# Well-written:
# If an employer refuses to pay owed wages, HMRC will issue a notice for the arrears as well as a fine. Moreover, HMRC retains the authority to take employers to court on behalf of the worker should they continue to refuse payment.
#
# Badly-written:
# Here’s the lowdown: if you find yourself in the unfortunate reality where your employer is pulling a vanishing act on your wages, HMRC is there to swoop in with their Notice of Arrears and, like, slap a fine on your employer too! And let's be real here – if they keep playing hardball and act all stubborn about it, HMRC isn’t just gonna stand back and wave goodbye – they can actually drag them to court on your behalf! How about that for a turn of events, huh?
# --------------------------------------------------------------------------------
#
# SNIPPET PAIR 12:
#
# Well-written:
# Workers have the option to approach an employment tribunal directly for disputes regarding minimum wage or unfair dismissal if they have been terminated due to a wage-related argument.
#
# Badly-written:
# So, if you find yourself in the mind-boggling labyrinth of wage disputes and think your minimum wage rights are being stomped on, you can totally skip the chit-chat with your boss and just stroll right up to an employment tribunal, like a boss yourself! And oh my goodness, if they dared to dismiss you over this very issue? Well, guess what! You can also throw an unfair dismissal claim into the mix, which is like a double whammy in your legal favor – how cool is that?!
# --------------------------------------------------------------------------------
